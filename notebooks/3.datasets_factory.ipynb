# %%
# %load_ext autoreload
# %autoreload 2

# %%
import sys

sys.path.append("..")

from spatialrisk.dataset import Dataset
from spatialrisk.project import Project

# %% [markdown]
# ## Set user parameters

# %%
project_name = "mtq-refactor"

# Load the project from JSON
project = Project.load(project_name=project_name)
# Out:
# Loaded 3 model(s)
# ✓ Target set: forest_loss_2015_2020 (static)
# ✓ Features set: 8 variables
#   Static: altitude, protected_area, rivers_dist, roads_dist, slope, subj
#   Temporal (year: 2015): forest_gfc, towns_dist
# ✓ Target set: forest_loss_2020_2024 (static)
# ✓ Features set: 8 variables
#   Static: altitude, protected_area, rivers_dist, roads_dist, slope, subj
#   Temporal (year: 2020): forest_gfc, towns_dist
# Loaded 2 dataset(s)
# Project loaded from: /home/jserafini/Desktop/projects/spatial_risk/spatial-risk-module/data/mtq-refactor/mtq-refactor_project.json
# Loaded 23 processed variables

# %% [markdown]
#  # Create dataset 1

# %%
dataset1 = Dataset(project=project, name="calibration")

# %%
# if not parameters passed, the function will show all the available variables
dataset1.set_target()
# Out:
# 📊 Available target variables:
#   • altitude (static)
#   • forest_gfc (temporal: 2015, 2020, 2024)
#   • forest_gfc_edge (temporal: 2015, 2020, 2024)
#   • forest_loss_2015_2020 (static)
#   • forest_loss_2015_2024 (static)
#   • forest_loss_2020_2024 (static)
#   • protected_area (static)
#   • rivers (static)
#   • rivers_dist (static)
#   • roads (static)
#   • roads_dist (static)
#   • slope (static)
#   • subj (static)
#   • towns (temporal: 2015, 2020, 2024)
#   • towns_dist (temporal: 2015, 2020, 2024)
# ['altitude',
#  'forest_gfc',
#  'forest_gfc_edge',
#  'forest_loss_2015_2020',
#  'forest_loss_2015_2024',
#  'forest_loss_2020_2024',
#  'protected_area',
#  'rivers',
#  'rivers_dist',
#  'roads',
#  'roads_dist',
#  'slope',
#  'subj',
#  'towns',
#  'towns_dist']

# %%
dataset1.set_target("forest_loss_2015_2020")
dataset1.set_year(2015)  # This will set the year for time-dependent variables
dataset1.set_features(
    [
        "altitude",
        "forest_gfc",
        "forest_gfc_edge",
        "protected_area",
        "rivers_dist",
        "roads_dist",
        "slope",
        "subj",
        "towns_dist",
    ]
)
dataset1.validate()
dataset1.register(project)
# Out:
# ✓ Target set: forest_loss_2015_2020 (static)
# ✓ Year set: 2015
# ✓ All temporal variables available for this year
# ✓ Features set: 9 variables
#   Static: altitude, protected_area, rivers_dist, roads_dist, slope, subj
#   Temporal (year: 2015): forest_gfc, forest_gfc_edge, towns_dist
#
# 🔍 Validating dataset configuration...
# ✓ Checking variable existence...
# ✓ All variables exist
# ✓ All variables processed and available
# ✓ Checking spatial compatibility...
#
# ✅ Dataset validation passed!
#   Dataset registered as project.datasets['calibration']
# Project saved to: /home/jserafini/Desktop/projects/spatial_risk/spatial-risk-module/data/mtq-refactor/mtq-refactor_project.json

# %% [markdown]
# # Create dataset 2

# %%
dataset2 = Dataset(project=project, name="validation")
dataset2.set_target("forest_loss_2020_2024")
dataset2.set_year(2020)  # This will set the year for time-dependent variables
dataset2.set_features(
    [
        "altitude",
        "forest_gfc",
        "forest_gfc_edge",
        "protected_area",
        "rivers_dist",
        "roads_dist",
        "slope",
        "subj",
        "towns_dist",
    ]
)
dataset2.validate()
dataset2.register(project)
# Out:
# ✓ Target set: forest_loss_2020_2024 (static)
# ✓ Year set: 2020
# ✓ All temporal variables available for this year
# ✓ Features set: 9 variables
#   Static: altitude, protected_area, rivers_dist, roads_dist, slope, subj
#   Temporal (year: 2020): forest_gfc, forest_gfc_edge, towns_dist
#
# 🔍 Validating dataset configuration...
# ✓ Checking variable existence...
# ✓ All variables exist
# ✓ All variables processed and available
# ✓ Checking spatial compatibility...
#
# ✅ Dataset validation passed!
#   Dataset registered as project.datasets['validation']
# Project saved to: /home/jserafini/Desktop/projects/spatial_risk/spatial-risk-module/data/mtq-refactor/mtq-refactor_project.json

# %%
dataset2.show()
# Out:
# ✅ Displayed 10 variable(s) in 4×3 grid

# %%
dataset2.register(project)  # or project.add_dataset(dataset)
# Out:
#   Dataset registered as project.datasets['validation']
# Project saved to: /home/jserafini/Desktop/projects/spatial_risk/spatial-risk-module/data/mtq-refactor/mtq-refactor_project.json

# %%
dataset2
# Out:
# Dataset(target=LocalRasterVar(name='forest_loss_2020_2024', data_type='raster', year=None, active=True, tags=['deforestation', 'forest_loss', '2020_2024'], path=PosixPath('/home/jserafini/Desktop/projects/spatial_risk/spatial-risk-module/data/mtq-refactor/data/forest_loss_2020_2024_reprojected_matched.tif'), raster_type='categorical', post_processing=[], processing_history=['reprojected_matched'], default_crs='EPSG:5490', default_resolution=30.0), features=[LocalRasterVar(name='altitude', data_type='raster', year=None, active=True, tags=[], path=PosixPath('/home/jserafini/Desktop/projects/spatial_risk/spatial-risk-module/data/mtq-refactor/data/altitude_reprojected_matched.tif'), raster_type='continuous', post_processing=[], processing_history=['reprojected_matched'], default_crs='EPSG:5490', default_resolution=30.0), LocalRasterVar(name='forest_gfc', data_type='raster', year=2020, active=True, tags=['forest'], path=PosixPath('/home/jserafini/Desktop/projects/spatial_risk/spatial-risk-module/data/mtq-refactor/data/forest_gfc_reprojected_matched_2020.tif'), raster_type='categorical', post_processing=[], processing_history=['reprojected_matched'], default_crs='EPSG:5490', default_resolution=30.0), LocalRasterVar(name='forest_gfc_edge', data_type='raster', year=2020, active=True, tags=['forest'], path=PosixPath('/home/jserafini/Desktop/projects/spatial_risk/spatial-risk-module/data/mtq-refactor/data/forest_gfc_reprojected_matched_edge_2020.tif'), raster_type='continuous', post_processing=['edge'], processing_history=['reprojected_matched', 'edge'], default_crs='EPSG:5490', default_resolution=30.0), LocalRasterVar(name='protected_area', data_type='raster', year=None, active=True, tags=[], path=PosixPath('/home/jserafini/Desktop/projects/spatial_risk/spatial-risk-module/data/mtq-refactor/data/protected_area_reprojected_matched.tif'), raster_type='categorical', post_processing=[], processing_history=['reprojected_matched'], default_crs='EPSG:5490', default_resolution=30.0), LocalRasterVar(name='rivers_dist', data_type='raster', year=None, active=True, tags=['river'], path=PosixPath('/home/jserafini/Desktop/projects/spatial_risk/spatial-risk-module/data/mtq-refactor/data/rivers_reprojected_matched_dist.tif'), raster_type='continuous', post_processing=['dist'], processing_history=['reprojected_matched', 'dist'], default_crs='EPSG:5490', default_resolution=30.0), LocalRasterVar(name='roads_dist', data_type='raster', year=None, active=True, tags=[], path=PosixPath('/home/jserafini/Desktop/projects/spatial_risk/spatial-risk-module/data/mtq-refactor/data/roads_reprojected_matched_dist.tif'), raster_type='continuous', post_processing=['dist'], processing_history=['reprojected_matched', 'dist'], default_crs='EPSG:5490', default_resolution=30.0), LocalRasterVar(name='slope', data_type='raster', year=None, active=True, tags=[], path=PosixPath('/home/jserafini/Desktop/projects/spatial_risk/spatial-risk-module/data/mtq-refactor/data/slope_reprojected_matched.tif'), raster_type='continuous', post_processing=[], processing_history=['reprojected_matched'], default_crs='EPSG:5490', default_resolution=30.0), LocalRasterVar(name='subj', data_type='raster', year=None, active=True, tags=[], path=PosixPath('/home/jserafini/Desktop/projects/spatial_risk/spatial-risk-module/data/mtq-refactor/data/subj_reprojected_matched.tif'), raster_type='categorical', post_processing=[], processing_history=['reprojected_matched'], default_crs='EPSG:5490', default_resolution=30.0), LocalRasterVar(name='towns_dist', data_type='raster', year=2020, active=True, tags=['town'], path=PosixPath('/home/jserafini/Desktop/projects/spatial_risk/spatial-risk-module/data/mtq-refactor/data/towns_reprojected_matched_dist_2020.tif'), raster_type='continuous', post_processing=['dist'], processing_history=['reprojected_matched', 'dist'], default_crs='EPSG:5490', default_resolution=30.0)], year=2020, name='validation')
